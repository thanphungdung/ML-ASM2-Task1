# %%
import tensorflow as tf
from keras import layers, models
import matplotlib.pyplot as plt
import keras_tuner as kt

# %%
IMGAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "train_images",
    shuffle=True,
    image_size = (IMGAGE_SIZE, IMGAGE_SIZE),
    batch_size = BATCH_SIZE,
)
# Out:
# Found 10407 files belonging to 10 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
for image_batch, label_batch in dataset.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")
    plt.show()

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1,test_split = 0.1, shuffle=True, shuffle_size=10000):
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    train_size = int(train_split * len(ds))
    val_size = int(val_split * len(ds))
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size + val_size)
    return train_ds, val_ds, test_ds

# %%
from tensorflow.python.client import device_lib
import tensorflow as tf

# List all physical GPU devices
gpus = tf.config.list_physical_devices('GPU')
print("Available GPU devices:")
for gpu in gpus:
    print(gpu)

# More detailed device info
print("\nDetailed device info:")
print(device_lib.list_local_devices())
# Out:
# Available GPU devices:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
# Detailed device info:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4210185600182925144
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5713690624
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2527036883846225085
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9"
# xla_global_id: 416903419
# ]

# %%
train_ds,val_ds,test_ds = get_dataset_partitions_tf(dataset)
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (260, 32, 34)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMGAGE_SIZE, IMGAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.Resizing(IMGAGE_SIZE, IMGAGE_SIZE),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.Rescaling(1./255)  # Do rescale last to keep image values valid
])

# %%
train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y))
val_ds = val_ds.map(lambda x, y: (resize_and_rescale(x), y))
test_ds = test_ds.map(lambda x, y: (resize_and_rescale(x), y))
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
for image_batch, label_batch in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")
    plt.show()

# %%
input_shape = (IMGAGE_SIZE, IMGAGE_SIZE, CHANNELS)
n_classes = 10
def build_model(hp, input_shape, n_classes):
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))
    # Fixed Conv blocks (as you already found effective)
    model.add(layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))

    # 🔧 Tune dropout rate
    model.add(layers.Dropout(hp.Choice('dropout', [0.2, 0.3, 0.4])))

    model.add(layers.Dense(n_classes, activation='softmax'))

    # 🔧 Tune learning rate
    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

tuner = kt.RandomSearch(
    lambda hp: build_model(hp, input_shape, n_classes),
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='kt_dir',
    project_name='cnn_tuning'
)

# %%
tuner = kt.RandomSearch(
    lambda hp: build_model(hp, input_shape, n_classes),
    objective='val_accuracy',
    max_trials=6,
    executions_per_trial=1,
    directory='kt_logs',
    project_name='tune_lr_dropout'
)
# Out:
# Reloading Tuner from kt_logs\tune_lr_dropout\tuner0.json

# %%
tuner.search(train_ds, validation_data=val_ds, epochs=5)

# %%
best_hp = tuner.get_best_hyperparameters(1)[0]
best_hp.values
# Out:
# {'dropout': 0.2, 'learning_rate': 0.001}

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=8,
    verbose=1,
    mode='auto',
    restore_best_weights=True
)
best_model = build_model(best_hp, input_shape, n_classes)

# Retrain longer with best settings
history = best_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,

)
# Out:
# Epoch 1/50
# 260/260 [==============================] - 63s 164ms/step - loss: 1.8949 - accuracy: 0.3296 - val_loss: 2.0376 - val_accuracy: 0.2012
# Epoch 2/50
# 260/260 [==============================] - 36s 124ms/step - loss: 1.6240 - accuracy: 0.4469 - val_loss: 1.4326 - val_accuracy: 0.4941
# Epoch 3/50
# 260/260 [==============================] - 37s 128ms/step - loss: 1.4394 - accuracy: 0.5071 - val_loss: 2.7087 - val_accuracy: 0.2188
# Epoch 4/50
# 260/260 [==============================] - 36s 121ms/step - loss: 1.3296 - accuracy: 0.5470 - val_loss: 2.0305 - val_accuracy: 0.4084
# Epoch 5/50
# 260/260 [==============================] - 36s 123ms/step - loss: 1.2229 - accuracy: 0.5846 - val_loss: 0.9580 - val_accuracy: 0.6807
# Epoch 6/50
# 260/260 [==============================] - 36s 122ms/step - loss: 1.1236 - accuracy: 0.6146 - val_loss: 0.8804 - val_accuracy: 0.7168
# Epoch 7/50
# 260/260 [==============================] - 37s 126ms/step - loss: 1.0607 - accuracy: 0.6356 - val_loss: 1.3792 - val_accuracy: 0.5352
# Epoch 8/50
# 260/260 [==============================] - 42s 146ms/step - loss: 1.0017 - accuracy: 0.6640 - val_loss: 1.4959 - val_accuracy: 0.5107
# Epoch 31/50
# 260/260 [==============================] - 38s 131ms/step - loss: 0.4185 - accuracy: 0.8528 - val_loss: 0.5728 - val_accuracy: 0.8350
# Epoch 32/50
# 260/260 [==============================] - 36s 124ms/step - loss: 0.4151 - accuracy: 0.8556 - val_loss: 0.3545 - val_accuracy: 0.8889
# Epoch 33/50
# 260/260 [==============================] - 36s 124ms/step - loss: 0.4037 - accuracy: 0.8643 - val_loss: 0.3191 - val_accuracy: 0.8975
# Epoch 34/50
# 260/260 [==============================] - 36s 123ms/step - loss: 0.3885 - accuracy: 0.8652 - val_loss: 0.4057 - val_accuracy: 0.8779
# Epoch 35/50
# 260/260 [==============================] - 37s 128ms/step - loss: 0.3839 - accuracy: 0.8682 - val_loss: 0.3579 - val_accuracy: 0.8926
# Epoch 36/50
# 260/260 [==============================] - 36s 126ms/step - loss: 0.3650 - accuracy: 0.8747 - val_loss: 0.1734 - val_accuracy: 0.9463
# Epoch 37/50
# 260/260 [==============================] - 37s 129ms/step - loss: 0.3718 - accuracy: 0.8752 - val_loss: 0.7243 - val_accuracy: 0.8008
# Epoch 38/50
# 260/260 [==============================] - 37s 126ms/step - loss: 0.3605 - accuracy: 0.8740 - val_loss: 0.3012 - val_accuracy: 0.8949
# Epoch 39/50
# 260/260 [==============================] - 39s 135ms/step - loss: 0.3611 - accuracy: 0.8766 - val_loss: 0.5637 - val_accuracy: 0.8271
# Epoch 40/50
# 260/260 [==============================] - 47s 165ms/step - loss: 0.3445 - accuracy: 0.8841 - val_loss: 0.3558 - val_accuracy: 0.8926
# Epoch 41/50
# 260/260 [==============================] - 42s 146ms/step - loss: 0.3421 - accuracy: 0.8817 - val_loss: 0.7595 - val_accuracy: 0.7783
# Epoch 42/50
# 260/260 [==============================] - 41s 144ms/step - loss: 0.3327 - accuracy: 0.8858 - val_loss: 0.1816 - val_accuracy: 0.9365
# Epoch 43/50
# 260/260 [==============================] - 38s 131ms/step - loss: 0.3478 - accuracy: 0.8811 - val_loss: 0.5422 - val_accuracy: 0.8252
# Epoch 44/50
# 260/260 [==============================] - 37s 127ms/step - loss: 0.3332 - accuracy: 0.8833 - val_loss: 0.7632 - val_accuracy: 0.7783
# Epoch 45/50
# 260/260 [==============================] - 37s 127ms/step - loss: 0.3153 - accuracy: 0.8922 - val_loss: 0.5277 - val_accuracy: 0.8271
# Epoch 46/50
# 260/260 [==============================] - 38s 131ms/step - loss: 0.3150 - accuracy: 0.8948 - val_loss: 0.6865 - val_accuracy: 0.8379
# Epoch 47/50
# 260/260 [==============================] - 38s 133ms/step - loss: 0.3084 - accuracy: 0.8957 - val_loss: 0.1829 - val_accuracy: 0.9375
# Epoch 48/50
# 260/260 [==============================] - 43s 149ms/step - loss: 0.3177 - accuracy: 0.8937 - val_loss: 0.5605 - val_accuracy: 0.8428
# Epoch 49/50
# 260/260 [==============================] - 39s 129ms/step - loss: 0.3033 - accuracy: 0.8967 - val_loss: 0.1862 - val_accuracy: 0.9443
# Epoch 50/50
# 260/260 [==============================] - 37s 125ms/step - loss: 0.2877 - accuracy: 0.8993 - val_loss: 0.4283 - val_accuracy: 0.8770

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_loss, test_acc = best_model.evaluate(test_ds)
print(f"✅ Test Accuracy: {test_acc:.4f}")
print(f"🧪 Test Loss: {test_loss:.4f}")
# Out:
# 34/34 [==============================] - 6s 21ms/step - loss: 0.3614 - accuracy: 0.8833
# ✅ Test Accuracy: 0.8833
# 🧪 Test Loss: 0.3614

# %%
from keras.models import load_model
best_model.save('best_model.h5')
